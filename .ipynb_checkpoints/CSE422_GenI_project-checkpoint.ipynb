# %%
import pandas as pd
import numpy as np
import librosa
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, Dropout, Flatten, Input
from keras.layers import *
from keras.models import Sequential, Model
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import random
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, LearningRateScheduler
max_length = 129270
epochs = 20
import seaborn as sn

# %%
tsv_path = './cv-corpus-10.0-2022-07-04/bn/validated.tsv'

# %%
df = pd.read_table(tsv_path)
df = df.drop(['client_id',  'sentence', 'up_votes', 'down_votes', 'age', 'accents', 'locale', 'segment'], axis=1)

df = df.to_numpy()

audio_list_males = []
audio_list_females = []


for i in range(len(df)):
    if df[i][1] == 'male':
        audio_list_males.append(df[i][0])
    elif df[i][1] == 'female':
        audio_list_females.append(df[i][0])

# %%
audio_list_males = audio_list_males[0:len(audio_list_females)]

print(len(audio_list_males), 'males')
print(len(audio_list_females), 'females')
# Out:
# 1751 males
# 1751 females

# %%
audio_list = audio_list_males + audio_list_females
audio_labels = []
for i in range(len(audio_list_males)):
    audio_labels.append(1)

for i in range(len(audio_list_females)):
    audio_labels.append(0)

# %%
len(audio_list)
# Out:
# 3502

# %%
X_train, X_test, y_train, y_test = train_test_split(audio_list, audio_labels, test_size=0.1, random_state=42)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
def padarray(A, size):
    t = size - len(A)
    return np.pad(A, pad_width=(0, t), mode='constant')

# %%
audio_path = './cv-corpus-10.0-2022-07-04/bn/clips/'

y, sr = librosa.load(audio_path+audio_list[1], sr=16000)

shape = y.shape[0]


if shape < max_length:
    y = padarray(y, max_length)

y = y[0:max_length]

stft = librosa.stft(y,  n_fft=1000)
db_scaled = librosa.amplitude_to_db(np.abs(stft))

plt.imshow(db_scaled)

print(y.shape)

print(stft.shape)
# Out:
# (129270,)
# (501, 518)

# %%
batch_size = 16
def loader(audio_list, audio_list_labels):
    
    audio_path = './cv-corpus-10.0-2022-07-04/bn/clips/'
    
    L = len(audio_list)
    while True:
        batch_start = 0
        batch_end = batch_size
        while batch_start < L:
            limit = min(batch_end, L)
            z = np.zeros((len(audio_list[batch_start:limit]), 501, 518))
            for i, f in enumerate(audio_list[batch_start:limit]):
                
                y, sr = librosa.load(audio_path+f, sr=16000)
                
                

                shape = y.shape[0]


                if shape < max_length:
                    y = padarray(y, max_length)

                y = y[0:max_length]

                stft = librosa.stft(y,  n_fft=1000)
                
                stft = librosa.util.normalize(stft)
                
                stft = np.real(stft)
                
                z[i, :, :] = stft

            X = np.expand_dims(z, axis=-1)
            Y = np.array(audio_list_labels[batch_start:limit])
            yield (X,Y)
            batch_start += batch_size   
            batch_end += batch_size
            
train_loader = loader(X_train, y_train)
val_loader = loader(X_val, y_val)

# %%
x, y = train_loader.__next__()

# %%
resnet50 = tf.keras.applications.ResNet50(
    include_top=False,
    weights=None,
    input_shape=(501, 518, 1),
    pooling=None,
)
resnet50.summary()

model = Sequential()
model.add(resnet50)
model.add(GlobalAveragePooling2D())
model.add(Dense(units=2, activation='softmax'))

loss = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=False, reduction="auto", name="sparse_categorical_crossentropy"
)

metrics = ['accuracy']
optimizer = Adam(0.001)

media_start = './'

es = tf.keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    min_delta=0,
    patience=20,
    verbose=1,
    mode="auto"
)

filepath= media_start+"resnet50.hdf5"

checkpoint = ModelCheckpoint(filepath, save_freq="epoch",save_best_only=True,
    save_weights_only=True, monitor='val_accuracy', verbose=1)

csv_logger = CSVLogger(media_start+"resnet50-log.csv")


model.compile(optimizer = optimizer, loss=loss, metrics=metrics)

train_steps = len(X_train)//batch_size
val_steps = len(X_val)//batch_size



history = model.fit(train_loader,
        steps_per_epoch=train_steps,
        epochs=epochs,
        verbose=1,
        validation_data=val_loader,
        validation_steps=val_steps,
        callbacks=[checkpoint, csv_logger]
)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('ResNet50')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('ResNet50')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

# Loading best model weights
model.load_weights('resnet50.hdf5')

predictions = np.zeros((len(X_test), 2))

for i, f in enumerate(X_test):
    y, sr = librosa.load(audio_path+f, sr=16000)



    shape = y.shape[0]


    if shape < max_length:
        y = padarray(y, max_length)

    y = y[0:max_length]

    stft = librosa.stft(y, n_fft=1000)

    stft = librosa.util.normalize(stft)

    stft = np.real(stft)
    
    data = stft
    data = np.expand_dims(np.expand_dims(data, axis=-1), axis=0)
    p = model.predict(data, verbose=0)
    predictions[i, :] = p
    
print("For ResNet50")
y_pred = np.argmax(predictions, axis=1)
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))

plt.figure(figsize = (10,7))
cm = confusion_matrix(y_test, y_pred)
sn.heatmap(cm, annot=True, fmt=".0f")
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 501, 518, 1  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 507, 524, 1)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 251, 259, 64  3200        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 251, 259, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 251, 259, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 253, 261, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 126, 130, 64  0           ['pool1_pad[0][0]']
#                                 )
#
#  conv2_block1_1_conv (Conv2D)   (None, 126, 130, 64  4160        ['pool1_pool[0][0]']
#                                 )
#
#  conv2_block1_1_bn (BatchNormal  (None, 126, 130, 64  256        ['conv2_block1_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_1_relu (Activatio  (None, 126, 130, 64  0          ['conv2_block1_1_bn[0][0]']
#  n)                             )
#
#  conv2_block1_2_conv (Conv2D)   (None, 126, 130, 64  36928       ['conv2_block1_1_relu[0][0]']
#                                 )
#
#  conv2_block1_2_bn (BatchNormal  (None, 126, 130, 64  256        ['conv2_block1_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_2_relu (Activatio  (None, 126, 130, 64  0          ['conv2_block1_2_bn[0][0]']
#  n)                             )
#
#  conv2_block1_0_conv (Conv2D)   (None, 126, 130, 25  16640       ['pool1_pool[0][0]']
#                                 6)
#
#  conv2_block1_3_conv (Conv2D)   (None, 126, 130, 25  16640       ['conv2_block1_2_relu[0][0]']
#                                 6)
#
#  conv2_block1_0_bn (BatchNormal  (None, 126, 130, 25  1024       ['conv2_block1_0_conv[0][0]']
#  ization)                       6)
#
#  conv2_block1_3_bn (BatchNormal  (None, 126, 130, 25  1024       ['conv2_block1_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block1_add (Add)         (None, 126, 130, 25  0           ['conv2_block1_0_bn[0][0]',
#                                 6)                                'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 126, 130, 25  0           ['conv2_block1_add[0][0]']
#                                 6)
#
#  conv2_block2_1_conv (Conv2D)   (None, 126, 130, 64  16448       ['conv2_block1_out[0][0]']
#                                 )
#
#  conv2_block2_1_bn (BatchNormal  (None, 126, 130, 64  256        ['conv2_block2_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_1_relu (Activatio  (None, 126, 130, 64  0          ['conv2_block2_1_bn[0][0]']
#  n)                             )
#
#  conv2_block2_2_conv (Conv2D)   (None, 126, 130, 64  36928       ['conv2_block2_1_relu[0][0]']
#                                 )
#
#  conv2_block2_2_bn (BatchNormal  (None, 126, 130, 64  256        ['conv2_block2_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_2_relu (Activatio  (None, 126, 130, 64  0          ['conv2_block2_2_bn[0][0]']
#  n)                             )
#
#  conv2_block2_3_conv (Conv2D)   (None, 126, 130, 25  16640       ['conv2_block2_2_relu[0][0]']
#                                 6)
#
#  conv2_block2_3_bn (BatchNormal  (None, 126, 130, 25  1024       ['conv2_block2_3_conv[0][0]']
#  ization)                       6)
#  conv2_block2_add (Add)         (None, 126, 130, 25  0           ['conv2_block1_out[0][0]',
#                                 6)                                'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 126, 130, 25  0           ['conv2_block2_add[0][0]']
#                                 6)
#
#  conv2_block3_1_conv (Conv2D)   (None, 126, 130, 64  16448       ['conv2_block2_out[0][0]']
#                                 )
#
#  conv2_block3_1_bn (BatchNormal  (None, 126, 130, 64  256        ['conv2_block3_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_1_relu (Activatio  (None, 126, 130, 64  0          ['conv2_block3_1_bn[0][0]']
#  n)                             )
#
#  conv2_block3_2_conv (Conv2D)   (None, 126, 130, 64  36928       ['conv2_block3_1_relu[0][0]']
#                                 )
#
#  conv2_block3_2_bn (BatchNormal  (None, 126, 130, 64  256        ['conv2_block3_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_2_relu (Activatio  (None, 126, 130, 64  0          ['conv2_block3_2_bn[0][0]']
#  n)                             )
#
#  conv2_block3_3_conv (Conv2D)   (None, 126, 130, 25  16640       ['conv2_block3_2_relu[0][0]']
#                                 6)
#
#  conv2_block3_3_bn (BatchNormal  (None, 126, 130, 25  1024       ['conv2_block3_3_conv[0][0]']
#  ization)                       6)
#
#  conv2_block3_add (Add)         (None, 126, 130, 25  0           ['conv2_block2_out[0][0]',
#                                 6)                                'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 126, 130, 25  0           ['conv2_block3_add[0][0]']
#                                 6)
#
#  conv3_block1_1_conv (Conv2D)   (None, 63, 65, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 63, 65, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 63, 65, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 63, 65, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 63, 65, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 63, 65, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 63, 65, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 63, 65, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 63, 65, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 63, 65, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 63, 65, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 63, 65, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 63, 65, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 63, 65, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 63, 65, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 63, 65, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 63, 65, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 63, 65, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#  conv3_block2_3_conv (Conv2D)   (None, 63, 65, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 63, 65, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 63, 65, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 63, 65, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 63, 65, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 63, 65, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 63, 65, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 63, 65, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 63, 65, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 63, 65, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 63, 65, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 63, 65, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 63, 65, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 63, 65, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 63, 65, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 63, 65, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 63, 65, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 63, 65, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 63, 65, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 63, 65, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 63, 65, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 63, 65, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 63, 65, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 63, 65, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 32, 33, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 32, 33, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 32, 33, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 32, 33, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 32, 33, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 32, 33, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 32, 33, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 32, 33, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 32, 33, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 32, 33, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 32, 33, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 32, 33, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 32, 33, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 32, 33, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 32, 33, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 32, 33, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 32, 33, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 32, 33, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 32, 33, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 32, 33, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 32, 33, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 32, 33, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 32, 33, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 32, 33, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 32, 33, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 32, 33, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 32, 33, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 32, 33, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 32, 33, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 32, 33, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 32, 33, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 32, 33, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 32, 33, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 32, 33, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 32, 33, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 32, 33, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 32, 33, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 32, 33, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 32, 33, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 32, 33, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 32, 33, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 32, 33, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 32, 33, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 32, 33, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 32, 33, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 32, 33, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 32, 33, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 32, 33, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 32, 33, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 32, 33, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 32, 33, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 32, 33, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 32, 33, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 32, 33, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 32, 33, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 32, 33, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 32, 33, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 32, 33, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 32, 33, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 32, 33, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 32, 33, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 32, 33, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 16, 17, 512)  524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 16, 17, 512)  2048       ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 16, 17, 512)  0          ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 16, 17, 512)  2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 16, 17, 512)  2048       ['conv5_block1_2_conv[0][0]']
#  ization)
#  conv5_block1_2_relu (Activatio  (None, 16, 17, 512)  0          ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 16, 17, 2048  2099200     ['conv4_block6_out[0][0]']
#                                 )
#
#  conv5_block1_3_conv (Conv2D)   (None, 16, 17, 2048  1050624     ['conv5_block1_2_relu[0][0]']
#                                 )
#
#  conv5_block1_0_bn (BatchNormal  (None, 16, 17, 2048  8192       ['conv5_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv5_block1_3_bn (BatchNormal  (None, 16, 17, 2048  8192       ['conv5_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block1_add (Add)         (None, 16, 17, 2048  0           ['conv5_block1_0_bn[0][0]',
#                                 )                                 'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 16, 17, 2048  0           ['conv5_block1_add[0][0]']
#                                 )
#
#  conv5_block2_1_conv (Conv2D)   (None, 16, 17, 512)  1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 16, 17, 512)  2048       ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 16, 17, 512)  0          ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 16, 17, 512)  2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 16, 17, 512)  2048       ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 16, 17, 512)  0          ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 16, 17, 2048  1050624     ['conv5_block2_2_relu[0][0]']
#                                 )
#
#  conv5_block2_3_bn (BatchNormal  (None, 16, 17, 2048  8192       ['conv5_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block2_add (Add)         (None, 16, 17, 2048  0           ['conv5_block1_out[0][0]',
#                                 )                                 'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 16, 17, 2048  0           ['conv5_block2_add[0][0]']
#                                 )
#
#  conv5_block3_1_conv (Conv2D)   (None, 16, 17, 512)  1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 16, 17, 512)  2048       ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 16, 17, 512)  0          ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 16, 17, 512)  2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 16, 17, 512)  2048       ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 16, 17, 512)  0          ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 16, 17, 2048  1050624     ['conv5_block3_2_relu[0][0]']
#                                 )
#
#  conv5_block3_3_bn (BatchNormal  (None, 16, 17, 2048  8192       ['conv5_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv5_block3_add (Add)         (None, 16, 17, 2048  0           ['conv5_block2_out[0][0]',
#                                 )                                 'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 16, 17, 2048  0           ['conv5_block3_add[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 23,581,440
# Trainable params: 23,528,320
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3937 - accuracy: 0.8622
# Epoch 1: val_accuracy improved from -inf to 0.48718, saving model to .\resnet50.hdf5
# 157/157 [==============================] - 174s 1s/step - loss: 0.3937 - accuracy: 0.8622 - val_loss: 0.7007 - val_accuracy: 0.4872
# Epoch 2/20
# 157/157 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9319
# Epoch 2: val_accuracy did not improve from 0.48718
# 157/157 [==============================] - 91s 579ms/step - loss: 0.1987 - accuracy: 0.9319 - val_loss: 1.8358 - val_accuracy: 0.4872
# Epoch 3/20
# 157/157 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9601
# Epoch 3: val_accuracy improved from 0.48718 to 0.50160, saving model to .\resnet50.hdf5
# 157/157 [==============================] - 97s 619ms/step - loss: 0.1270 - accuracy: 0.9601 - val_loss: 1.1627 - val_accuracy: 0.5016
# Epoch 4/20
# 157/157 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9641
# Epoch 4: val_accuracy improved from 0.50160 to 0.76763, saving model to .\resnet50.hdf5
# 157/157 [==============================] - 97s 618ms/step - loss: 0.1220 - accuracy: 0.9641 - val_loss: 0.4572 - val_accuracy: 0.7676
# Epoch 5/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9788
# Epoch 5: val_accuracy improved from 0.76763 to 0.94551, saving model to .\resnet50.hdf5
# 157/157 [==============================] - 97s 618ms/step - loss: 0.0815 - accuracy: 0.9788 - val_loss: 0.1902 - val_accuracy: 0.9455
# Epoch 6/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9828
# Epoch 6: val_accuracy improved from 0.94551 to 0.95513, saving model to .\resnet50.hdf5
# 157/157 [==============================] - 96s 615ms/step - loss: 0.0554 - accuracy: 0.9828 - val_loss: 0.2593 - val_accuracy: 0.9551
# Epoch 7/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9772
# Epoch 7: val_accuracy did not improve from 0.95513
# 157/157 [==============================] - 92s 586ms/step - loss: 0.0613 - accuracy: 0.9772 - val_loss: 0.1980 - val_accuracy: 0.9471
# Epoch 8/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9792
# Epoch 8: val_accuracy did not improve from 0.95513
# 157/157 [==============================] - 92s 589ms/step - loss: 0.0631 - accuracy: 0.9792 - val_loss: 8.8237 - val_accuracy: 0.5321
# Epoch 9/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9840
# Epoch 9: val_accuracy did not improve from 0.95513
# 157/157 [==============================] - 92s 588ms/step - loss: 0.0574 - accuracy: 0.9840 - val_loss: 2.8838 - val_accuracy: 0.7500
# Epoch 10/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9908
# Epoch 10: val_accuracy did not improve from 0.95513
# 157/157 [==============================] - 92s 590ms/step - loss: 0.0312 - accuracy: 0.9908 - val_loss: 0.3045 - val_accuracy: 0.8734
# Epoch 11/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9928
# Epoch 11: val_accuracy did not improve from 0.95513
# 157/157 [==============================] - 109s 694ms/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.5388 - val_accuracy: 0.9327
# Epoch 12/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9880
# Epoch 12: val_accuracy did not improve from 0.95513
# 157/157 [==============================] - 96s 612ms/step - loss: 0.0376 - accuracy: 0.9880 - val_loss: 1.2536 - val_accuracy: 0.8494
# Epoch 13/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9972
# Epoch 13: val_accuracy did not improve from 0.95513
# 157/157 [==============================] - 94s 599ms/step - loss: 0.0107 - accuracy: 0.9972 - val_loss: 0.4319 - val_accuracy: 0.9503
# Epoch 14/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9752
# Epoch 14: val_accuracy did not improve from 0.95513
# 157/157 [==============================] - 94s 599ms/step - loss: 0.0705 - accuracy: 0.9752 - val_loss: 2.3445 - val_accuracy: 0.7452
# Epoch 15/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9904
# Epoch 15: val_accuracy did not improve from 0.95513
# 157/157 [==============================] - 91s 579ms/step - loss: 0.0272 - accuracy: 0.9904 - val_loss: 0.5811 - val_accuracy: 0.9423
# Epoch 16/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9936
# Epoch 16: val_accuracy did not improve from 0.95513
# 157/157 [==============================] - 91s 577ms/step - loss: 0.0172 - accuracy: 0.9936 - val_loss: 0.3693 - val_accuracy: 0.8141
# Epoch 17/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9784
# Epoch 17: val_accuracy did not improve from 0.95513
# 157/157 [==============================] - 91s 578ms/step - loss: 0.0755 - accuracy: 0.9784 - val_loss: 4.9122 - val_accuracy: 0.5577
# Epoch 18/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9952
# Epoch 18: val_accuracy improved from 0.95513 to 0.97276, saving model to .\resnet50.hdf5
# 157/157 [==============================] - 94s 600ms/step - loss: 0.0189 - accuracy: 0.9952 - val_loss: 0.1568 - val_accuracy: 0.9728
# Epoch 19/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9984
# Epoch 19: val_accuracy did not improve from 0.97276
# 157/157 [==============================] - 91s 579ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.1752 - val_accuracy: 0.9551
# Epoch 20/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9948
# Epoch 20: val_accuracy did not improve from 0.97276
# 157/157 [==============================] - 91s 580ms/step - loss: 0.0123 - accuracy: 0.9948 - val_loss: 0.5592 - val_accuracy: 0.9423
# For ResNet50
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       162
#            1       0.96      0.97      0.97       189
#
#     accuracy                           0.96       351
#    macro avg       0.96      0.96      0.96       351
# weighted avg       0.96      0.96      0.96       351
#
# 0.9629629629629629
# <Axes: >

# %%
EfficientNetB0 = tf.keras.applications.EfficientNetB0(
    include_top=False,
    weights=None,
    input_shape=(501, 518, 1),
    pooling=None,
)
EfficientNetB0.summary()

model = Sequential()
model.add(EfficientNetB0)
model.add(GlobalAveragePooling2D())
model.add(Dense(units=2, activation='softmax'))

loss = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=False, reduction="auto", name="sparse_categorical_crossentropy"
)

metrics = ['accuracy']
optimizer = Adam(0.001)

media_start = './'

es = tf.keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    min_delta=0,
    patience=20,
    verbose=1,
    mode="auto"
)

filepath= media_start+"EfficientNetB0.hdf5"

checkpoint = ModelCheckpoint(filepath, save_freq="epoch",save_best_only=True,
    save_weights_only=True, monitor='val_accuracy', verbose=1)

csv_logger = CSVLogger(media_start+"vgg-log.csv")


model.compile(optimizer = optimizer, loss=loss, metrics=metrics)

train_steps = len(X_train)//batch_size
val_steps = len(X_val)//batch_size



history = model.fit(train_loader,
        steps_per_epoch=train_steps,
        epochs=epochs,
        verbose=1,
        validation_data=val_loader,
        validation_steps=val_steps,
        callbacks=[checkpoint, csv_logger]
)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('EfficientNetB0')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('EfficientNetB0')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

# Loading best model weights
model.load_weights('EfficientNetB0.hdf5')

predictions = np.zeros((len(X_test), 2))

for i, f in enumerate(X_test):
    y, sr = librosa.load(audio_path+f, sr=16000)



    shape = y.shape[0]


    if shape < max_length:
        y = padarray(y, max_length)

    y = y[0:max_length]

    stft = librosa.stft(y, n_fft=1000)

    stft = librosa.util.normalize(stft)

    stft = np.real(stft)
    
    data = stft
    data = np.expand_dims(np.expand_dims(data, axis=-1), axis=0)
    p = model.predict(data, verbose=0)
    predictions[i, :] = p
    
print("For EfficientNetB0")
y_pred = np.argmax(predictions, axis=1)
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))

plt.figure(figsize = (10,7))
cm = confusion_matrix(y_test, y_pred)
sn.heatmap(cm, annot=True, fmt=".0f")
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 501, 518, 1  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 501, 518, 1)  0           ['input_2[0][0]']
#
#  normalization (Normalization)  (None, 501, 518, 1)  3           ['rescaling[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 503, 519, 1)  0           ['normalization[0][0]']
#
#  stem_conv (Conv2D)             (None, 251, 259, 32  288         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 251, 259, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 251, 259, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 251, 259, 32  288        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 251, 259, 32  128        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 251, 259, 32  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 251, 259, 32  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 251, 259, 16  512         ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 251, 259, 16  64         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block2a_expand_conv (Conv2D)   (None, 251, 259, 96  1536        ['block1a_project_bn[0][0]']
#                                 )
#
#  block2a_expand_bn (BatchNormal  (None, 251, 259, 96  384        ['block2a_expand_conv[0][0]']
#  ization)                       )
#
#  block2a_expand_activation (Act  (None, 251, 259, 96  0          ['block2a_expand_bn[0][0]']
#  ivation)                       )
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 253, 261, 96  0          ['block2a_expand_activation[0][0]
#  g2D)                           )                                ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 126, 130, 96  864        ['block2a_dwconv_pad[0][0]']
#  D)                             )
#
#  block2a_bn (BatchNormalization  (None, 126, 130, 96  384        ['block2a_dwconv[0][0]']
#  )                              )
#
#  block2a_activation (Activation  (None, 126, 130, 96  0          ['block2a_bn[0][0]']
#  )                              )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 126, 130, 96  0           ['block2a_activation[0][0]',
#                                 )                                 'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 126, 130, 24  2304        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 126, 130, 24  96         ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 126, 130, 14  3456        ['block2a_project_bn[0][0]']
#                                 4)
#
#  block2b_expand_bn (BatchNormal  (None, 126, 130, 14  576        ['block2b_expand_conv[0][0]']
#  ization)                       4)
#
#  block2b_expand_activation (Act  (None, 126, 130, 14  0          ['block2b_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2b_dwconv (DepthwiseConv2  (None, 126, 130, 14  1296       ['block2b_expand_activation[0][0]
#  D)                             4)                               ']
#
#  block2b_bn (BatchNormalization  (None, 126, 130, 14  576        ['block2b_dwconv[0][0]']
#  )                              4)
#
#  block2b_activation (Activation  (None, 126, 130, 14  0          ['block2b_bn[0][0]']
#  )                              4)
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 126, 130, 14  0           ['block2b_activation[0][0]',
#                                 4)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 126, 130, 24  3456        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 126, 130, 24  96         ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 126, 130, 24  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 126, 130, 24  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 126, 130, 14  3456        ['block2b_add[0][0]']
#                                 4)
#
#  block3a_expand_bn (BatchNormal  (None, 126, 130, 14  576        ['block3a_expand_conv[0][0]']
#  ization)                       4)
#
#  block3a_expand_activation (Act  (None, 126, 130, 14  0          ['block3a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 129, 133, 14  0          ['block3a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 63, 65, 144)  3600       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 63, 65, 144)  576        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 63, 65, 144)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 63, 65, 144)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 63, 65, 40)   5760        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 63, 65, 40)  160         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 63, 65, 240)  9600        ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 63, 65, 240)  960        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 63, 65, 240)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 63, 65, 240)  6000       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 63, 65, 240)  960        ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 63, 65, 240)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 240)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 63, 65, 240)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 63, 65, 40)   9600        ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 63, 65, 40)  160         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 63, 65, 40)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 63, 65, 40)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 63, 65, 240)  9600        ['block3b_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 63, 65, 240)  960        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 63, 65, 240)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 65, 67, 240)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 32, 33, 240)  2160       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 32, 33, 240)  960        ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 32, 33, 240)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 240)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 32, 33, 240)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 32, 33, 80)   19200       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 32, 33, 80)  320         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 32, 33, 480)  38400       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 32, 33, 480)  1920       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 32, 33, 480)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 32, 33, 480)  4320       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 32, 33, 480)  1920       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 32, 33, 480)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 480)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 32, 33, 480)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 32, 33, 80)   38400       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 32, 33, 80)  320         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 32, 33, 80)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 32, 33, 80)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 32, 33, 480)  38400       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 32, 33, 480)  1920       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 32, 33, 480)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 32, 33, 480)  4320       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 32, 33, 480)  1920       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 32, 33, 480)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 480)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 32, 33, 480)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 32, 33, 80)   38400       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 32, 33, 80)  320         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 32, 33, 80)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 32, 33, 80)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 32, 33, 480)  38400       ['block4c_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 32, 33, 480)  1920       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 32, 33, 480)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv (DepthwiseConv2  (None, 32, 33, 480)  12000      ['block5a_expand_activation[0][0]
#  D)                                                              ']
#  block5a_bn (BatchNormalization  (None, 32, 33, 480)  1920       ['block5a_dwconv[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 32, 33, 480)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 480)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 32, 33, 480)  0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 32, 33, 112)  53760       ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 32, 33, 112)  448        ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 32, 33, 672)  75264       ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 32, 33, 672)  2688       ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 32, 33, 672)  0          ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv (DepthwiseConv2  (None, 32, 33, 672)  16800      ['block5b_expand_activation[0][0]
#  D)                                                              ']
#
#  block5b_bn (BatchNormalization  (None, 32, 33, 672)  2688       ['block5b_dwconv[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 32, 33, 672)  0          ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 672)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 32, 33, 672)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 32, 33, 112)  75264       ['block5b_se_excite[0][0]']
#
#  block5b_project_bn (BatchNorma  (None, 32, 33, 112)  448        ['block5b_project_conv[0][0]']
#  lization)
#
#  block5b_drop (Dropout)         (None, 32, 33, 112)  0           ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)              (None, 32, 33, 112)  0           ['block5b_drop[0][0]',
#                                                                   'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2D)   (None, 32, 33, 672)  75264       ['block5b_add[0][0]']
#
#  block5c_expand_bn (BatchNormal  (None, 32, 33, 672)  2688       ['block5c_expand_conv[0][0]']
#  ization)
#
#  block5c_expand_activation (Act  (None, 32, 33, 672)  0          ['block5c_expand_bn[0][0]']
#  ivation)
#
#  block5c_dwconv (DepthwiseConv2  (None, 32, 33, 672)  16800      ['block5c_expand_activation[0][0]
#  D)                                                              ']
#
#  block5c_bn (BatchNormalization  (None, 32, 33, 672)  2688       ['block5c_dwconv[0][0]']
#  )
#
#  block5c_activation (Activation  (None, 32, 33, 672)  0          ['block5c_bn[0][0]']
#  )
#
#  block5c_se_squeeze (GlobalAver  (None, 672)         0           ['block5c_activation[0][0]']
#  agePooling2D)
#
#  block5c_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5c_se_squeeze[0][0]']
#
#  block5c_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multiply)   (None, 32, 33, 672)  0           ['block5c_activation[0][0]',
#                                                                   'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv2D)  (None, 32, 33, 112)  75264       ['block5c_se_excite[0][0]']
#
#  block5c_project_bn (BatchNorma  (None, 32, 33, 112)  448        ['block5c_project_conv[0][0]']
#  lization)
#
#  block5c_drop (Dropout)         (None, 32, 33, 112)  0           ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)              (None, 32, 33, 112)  0           ['block5c_drop[0][0]',
#                                                                   'block5b_add[0][0]']
#
#  block6a_expand_conv (Conv2D)   (None, 32, 33, 672)  75264       ['block5c_add[0][0]']
#
#  block6a_expand_bn (BatchNormal  (None, 32, 33, 672)  2688       ['block6a_expand_conv[0][0]']
#  ization)
#
#  block6a_expand_activation (Act  (None, 32, 33, 672)  0          ['block6a_expand_bn[0][0]']
#  ivation)
#
#  block6a_dwconv_pad (ZeroPaddin  (None, 35, 37, 672)  0          ['block6a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block6a_dwconv (DepthwiseConv2  (None, 16, 17, 672)  16800      ['block6a_dwconv_pad[0][0]']
#  D)
#
#  block6a_bn (BatchNormalization  (None, 16, 17, 672)  2688       ['block6a_dwconv[0][0]']
#  )
#
#  block6a_activation (Activation  (None, 16, 17, 672)  0          ['block6a_bn[0][0]']
#  )
#
#  block6a_se_squeeze (GlobalAver  (None, 672)         0           ['block6a_activation[0][0]']
#  agePooling2D)
#
#  block6a_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block6a_se_squeeze[0][0]']
#
#  block6a_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block6a_se_reshape[0][0]']
#
#  block6a_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block6a_se_reduce[0][0]']
#
#  block6a_se_excite (Multiply)   (None, 16, 17, 672)  0           ['block6a_activation[0][0]',
#                                                                   'block6a_se_expand[0][0]']
#
#  block6a_project_conv (Conv2D)  (None, 16, 17, 192)  129024      ['block6a_se_excite[0][0]']
#
#  block6a_project_bn (BatchNorma  (None, 16, 17, 192)  768        ['block6a_project_conv[0][0]']
#  lization)
#
#  block6b_expand_conv (Conv2D)   (None, 16, 17, 1152  221184      ['block6a_project_bn[0][0]']
#                                 )
#
#  block6b_expand_bn (BatchNormal  (None, 16, 17, 1152  4608       ['block6b_expand_conv[0][0]']
#  ization)                       )
#
#  block6b_expand_activation (Act  (None, 16, 17, 1152  0          ['block6b_expand_bn[0][0]']
#  ivation)                       )
#
#  block6b_dwconv (DepthwiseConv2  (None, 16, 17, 1152  28800      ['block6b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6b_bn (BatchNormalization  (None, 16, 17, 1152  4608       ['block6b_dwconv[0][0]']
#  )                              )
#
#  block6b_activation (Activation  (None, 16, 17, 1152  0          ['block6b_bn[0][0]']
#  )                              )
# ...
#
#  block6c_project_conv (Conv2D)  (None, 16, 17, 192)  221184      ['block6c_se_excite[0][0]']
#
#  block6c_project_bn (BatchNorma  (None, 16, 17, 192)  768        ['block6c_project_conv[0][0]']
#  lization)
#
#  block6c_drop (Dropout)         (None, 16, 17, 192)  0           ['block6c_project_bn[0][0]']
#
#  block6c_add (Add)              (None, 16, 17, 192)  0           ['block6c_drop[0][0]',
#                                                                   'block6b_add[0][0]']
#
#  block6d_expand_conv (Conv2D)   (None, 16, 17, 1152  221184      ['block6c_add[0][0]']
#                                 )
#
#  block6d_expand_bn (BatchNormal  (None, 16, 17, 1152  4608       ['block6d_expand_conv[0][0]']
#  ization)                       )
#
#  block6d_expand_activation (Act  (None, 16, 17, 1152  0          ['block6d_expand_bn[0][0]']
#  ivation)                       )
#
#  block6d_dwconv (DepthwiseConv2  (None, 16, 17, 1152  28800      ['block6d_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6d_bn (BatchNormalization  (None, 16, 17, 1152  4608       ['block6d_dwconv[0][0]']
#  )                              )
#
#  block6d_activation (Activation  (None, 16, 17, 1152  0          ['block6d_bn[0][0]']
#  )                              )
#
#  block6d_se_squeeze (GlobalAver  (None, 1152)        0           ['block6d_activation[0][0]']
#  agePooling2D)
#
#  block6d_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6d_se_squeeze[0][0]']
#
#  block6d_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multiply)   (None, 16, 17, 1152  0           ['block6d_activation[0][0]',
#                                 )                                 'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv2D)  (None, 16, 17, 192)  221184      ['block6d_se_excite[0][0]']
#
#  block6d_project_bn (BatchNorma  (None, 16, 17, 192)  768        ['block6d_project_conv[0][0]']
#  lization)
#
#  block6d_drop (Dropout)         (None, 16, 17, 192)  0           ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)              (None, 16, 17, 192)  0           ['block6d_drop[0][0]',
#                                                                   'block6c_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 16, 17, 1152  221184      ['block6d_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 16, 17, 1152  4608       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 16, 17, 1152  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 16, 17, 1152  10368      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 16, 17, 1152  4608       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 16, 17, 1152  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1152)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 16, 17, 1152  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 16, 17, 320)  368640      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 16, 17, 320)  1280       ['block7a_project_conv[0][0]']
#  lization)
#
#  top_conv (Conv2D)              (None, 16, 17, 1280  409600      ['block7a_project_bn[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 16, 17, 1280  5120        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 16, 17, 1280  0           ['top_bn[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 4,048,991
# Trainable params: 4,006,972
# Non-trainable params: 42,019
# __________________________________________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - ETA: 0s - loss: 0.4873 - accuracy: 0.7624
# Epoch 1: val_accuracy improved from -inf to 0.48718, saving model to .\EfficientNetB0.hdf5
# 157/157 [==============================] - 92s 535ms/step - loss: 0.4873 - accuracy: 0.7624 - val_loss: 0.6991 - val_accuracy: 0.4872
# Epoch 2/20
# 157/157 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9293
# Epoch 2: val_accuracy improved from 0.48718 to 0.51282, saving model to .\EfficientNetB0.hdf5
# 157/157 [==============================] - 82s 525ms/step - loss: 0.1988 - accuracy: 0.9293 - val_loss: 0.6940 - val_accuracy: 0.5128
# Epoch 3/20
# 157/157 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9692
# Epoch 3: val_accuracy did not improve from 0.51282
# 157/157 [==============================] - 77s 492ms/step - loss: 0.1019 - accuracy: 0.9692 - val_loss: 0.6927 - val_accuracy: 0.5128
# Epoch 4/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9748
# Epoch 4: val_accuracy improved from 0.51282 to 0.79968, saving model to .\EfficientNetB0.hdf5
# 157/157 [==============================] - 82s 524ms/step - loss: 0.0688 - accuracy: 0.9748 - val_loss: 0.4202 - val_accuracy: 0.7997
# Epoch 5/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9828
# Epoch 5: val_accuracy did not improve from 0.79968
# 157/157 [==============================] - 77s 491ms/step - loss: 0.0569 - accuracy: 0.9828 - val_loss: 1.0739 - val_accuracy: 0.5833
# Epoch 6/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9832
# Epoch 6: val_accuracy improved from 0.79968 to 0.83814, saving model to .\EfficientNetB0.hdf5
# 157/157 [==============================] - 81s 517ms/step - loss: 0.0531 - accuracy: 0.9832 - val_loss: 0.3222 - val_accuracy: 0.8381
# Epoch 7/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9820
# Epoch 7: val_accuracy did not improve from 0.83814
# 157/157 [==============================] - 77s 490ms/step - loss: 0.0473 - accuracy: 0.9820 - val_loss: 0.8953 - val_accuracy: 0.7548
# Epoch 8/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9884
# Epoch 8: val_accuracy did not improve from 0.83814
# 157/157 [==============================] - 77s 489ms/step - loss: 0.0392 - accuracy: 0.9884 - val_loss: 0.7020 - val_accuracy: 0.7019
# Epoch 9/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9868
# Epoch 9: val_accuracy improved from 0.83814 to 0.92949, saving model to .\EfficientNetB0.hdf5
# 157/157 [==============================] - 82s 520ms/step - loss: 0.0411 - accuracy: 0.9868 - val_loss: 0.2240 - val_accuracy: 0.9295
# Epoch 10/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9948
# Epoch 10: val_accuracy did not improve from 0.92949
# 157/157 [==============================] - 82s 521ms/step - loss: 0.0155 - accuracy: 0.9948 - val_loss: 0.3676 - val_accuracy: 0.8638
# Epoch 11/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9916
# Epoch 11: val_accuracy did not improve from 0.92949
# 157/157 [==============================] - 85s 542ms/step - loss: 0.0241 - accuracy: 0.9916 - val_loss: 0.7423 - val_accuracy: 0.6298
# Epoch 12/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9916
# Epoch 12: val_accuracy did not improve from 0.92949
# 157/157 [==============================] - 80s 509ms/step - loss: 0.0276 - accuracy: 0.9916 - val_loss: 0.2072 - val_accuracy: 0.9295
# Epoch 13/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9920
# Epoch 13: val_accuracy improved from 0.92949 to 0.93269, saving model to .\EfficientNetB0.hdf5
# 157/157 [==============================] - 86s 550ms/step - loss: 0.0253 - accuracy: 0.9920 - val_loss: 0.2066 - val_accuracy: 0.9327
# Epoch 14/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9884
# Epoch 14: val_accuracy did not improve from 0.93269
# 157/157 [==============================] - 77s 488ms/step - loss: 0.0317 - accuracy: 0.9884 - val_loss: 0.2852 - val_accuracy: 0.9038
# Epoch 15/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9960
# Epoch 15: val_accuracy improved from 0.93269 to 0.94231, saving model to .\EfficientNetB0.hdf5
# 157/157 [==============================] - 82s 522ms/step - loss: 0.0109 - accuracy: 0.9960 - val_loss: 0.2086 - val_accuracy: 0.9423
# Epoch 16/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9964
# Epoch 16: val_accuracy did not improve from 0.94231
# 157/157 [==============================] - 77s 491ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.3795 - val_accuracy: 0.8766
# Epoch 17/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9912
# Epoch 17: val_accuracy did not improve from 0.94231
# 157/157 [==============================] - 77s 491ms/step - loss: 0.0286 - accuracy: 0.9912 - val_loss: 0.9819 - val_accuracy: 0.6090
# Epoch 18/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9936
# Epoch 18: val_accuracy did not improve from 0.94231
# 157/157 [==============================] - 77s 490ms/step - loss: 0.0233 - accuracy: 0.9936 - val_loss: 0.2610 - val_accuracy: 0.9375
# Epoch 19/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9976
# Epoch 19: val_accuracy did not improve from 0.94231
# 157/157 [==============================] - 77s 493ms/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 0.3349 - val_accuracy: 0.9279
# Epoch 20/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9984
# Epoch 20: val_accuracy did not improve from 0.94231
# 157/157 [==============================] - 77s 490ms/step - loss: 0.0040 - accuracy: 0.9984 - val_loss: 0.3278 - val_accuracy: 0.9407
# For EfficientNetB0
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94       162
#            1       0.95      0.96      0.95       189
#
#     accuracy                           0.95       351
#    macro avg       0.95      0.95      0.95       351
# weighted avg       0.95      0.95      0.95       351
#
# 0.9487179487179487
# <Axes: >

# %%
iv3 = tf.keras.applications.InceptionV3(
    include_top=False,
    weights=None,
    input_shape=(501, 518, 1),
    pooling=None,
)
iv3.summary()

model = Sequential()
model.add(iv3)
model.add(GlobalAveragePooling2D())
model.add(Dense(units=2, activation='softmax'))

loss = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=False, reduction="auto", name="sparse_categorical_crossentropy"
)

metrics = ['accuracy']
optimizer = Adam(0.001)

media_start = './'

es = tf.keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    min_delta=0,
    patience=20,
    verbose=1,
    mode="auto"
)

filepath= media_start+"iv3.hdf5"

checkpoint = ModelCheckpoint(filepath, save_freq="epoch",save_best_only=True,
    save_weights_only=True, monitor='val_accuracy', verbose=1)

csv_logger = CSVLogger(media_start+"iv3-log.csv")


model.compile(optimizer = optimizer, loss=loss, metrics=metrics)

train_steps = len(X_train)//batch_size
val_steps = len(X_val)//batch_size



history = model.fit(train_loader,
        steps_per_epoch=train_steps,
        epochs=epochs,
        verbose=1,
        validation_data=val_loader,
        validation_steps=val_steps,
        callbacks=[checkpoint, csv_logger]
)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('InceptionV3')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('InceptionV3')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

# Loading best model weights
model.load_weights('iv3.hdf5')

predictions = np.zeros((len(X_test), 2))

for i, f in enumerate(X_test):
    y, sr = librosa.load(audio_path+f, sr=16000)



    shape = y.shape[0]


    if shape < max_length:
        y = padarray(y, max_length)

    y = y[0:max_length]

    stft = librosa.stft(y, n_fft=1000)

    stft = librosa.util.normalize(stft)

    stft = np.real(stft)
    
    data = stft
    data = np.expand_dims(np.expand_dims(data, axis=-1), axis=0)
    p = model.predict(data, verbose=0)
    predictions[i, :] = p
    
print("For InceptionV3")
y_pred = np.argmax(predictions, axis=1)
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))

plt.figure(figsize = (10,7))
cm = confusion_matrix(y_test, y_pred)
sn.heatmap(cm, annot=True, fmt=".0f")
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 501, 518, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 250, 258, 32  288         ['input_3[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 250, 258, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 250, 258, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 248, 256, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 248, 256, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 248, 256, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 248, 256, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 248, 256, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 248, 256, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 123, 127, 64  0           ['activation_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 123, 127, 80  5120        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 123, 127, 80  240        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 123, 127, 80  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 121, 125, 19  138240      ['activation_3[0][0]']
#                                 2)
#
#  batch_normalization_4 (BatchNo  (None, 121, 125, 19  576        ['conv2d_4[0][0]']
#  rmalization)                   2)
#
#  activation_4 (Activation)      (None, 121, 125, 19  0           ['batch_normalization_4[0][0]']
#                                 2)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 60, 62, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 60, 62, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 60, 62, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 60, 62, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 60, 62, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 60, 62, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 60, 62, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 60, 62, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 60, 62, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 60, 62, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 60, 62, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 60, 62, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 60, 62, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 60, 62, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 60, 62, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 60, 62, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 60, 62, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 60, 62, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 60, 62, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 60, 62, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 60, 62, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 60, 62, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 60, 62, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 60, 62, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 60, 62, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 60, 62, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 60, 62, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 60, 62, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 60, 62, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 60, 62, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 60, 62, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 60, 62, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 60, 62, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 60, 62, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 60, 62, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 60, 62, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 60, 62, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 60, 62, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 60, 62, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 60, 62, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 60, 62, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 60, 62, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 60, 62, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 60, 62, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 60, 62, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 60, 62, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 60, 62, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 60, 62, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 60, 62, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 60, 62, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 60, 62, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 60, 62, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 60, 62, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 60, 62, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 60, 62, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 60, 62, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 60, 62, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 60, 62, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 60, 62, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 60, 62, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 60, 62, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 60, 62, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 60, 62, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 60, 62, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 60, 62, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 60, 62, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 60, 62, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 60, 62, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 60, 62, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 60, 62, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 60, 62, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 60, 62, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 60, 62, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 60, 62, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 60, 62, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 60, 62, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 29, 30, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 29, 30, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 29, 30, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 29, 30, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 29, 30, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 29, 30, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 29, 30, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 29, 30, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 29, 30, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 29, 30, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 29, 30, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 29, 30, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 29, 30, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 29, 30, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 29, 30, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 29, 30, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 29, 30, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 29, 30, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 29, 30, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 29, 30, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 29, 30, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 29, 30, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 29, 30, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 29, 30, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 29, 30, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 29, 30, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 29, 30, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 29, 30, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 29, 30, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 29, 30, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 29, 30, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 29, 30, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 29, 30, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 29, 30, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 29, 30, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 29, 30, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 29, 30, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 29, 30, 192)  0           ['batch_normalization_38[0][0]']
#  activation_39 (Activation)     (None, 29, 30, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 29, 30, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 29, 30, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 29, 30, 160)  480        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 29, 30, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 29, 30, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 29, 30, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 29, 30, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 29, 30, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 29, 30, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 29, 30, 160)  480        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 29, 30, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 29, 30, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 29, 30, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 29, 30, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 29, 30, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 29, 30, 160)  480        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 29, 30, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 29, 30, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 29, 30, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 29, 30, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 29, 30, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 29, 30, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 29, 30, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 29, 30, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 29, 30, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 29, 30, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 29, 30, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 29, 30, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 29, 30, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 29, 30, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 29, 30, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 29, 30, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 29, 30, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 29, 30, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 29, 30, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 29, 30, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 29, 30, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 29, 30, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 29, 30, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 29, 30, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 29, 30, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 29, 30, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 29, 30, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 29, 30, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 29, 30, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 29, 30, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 29, 30, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 29, 30, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 29, 30, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 29, 30, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 29, 30, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 29, 30, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 29, 30, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 29, 30, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 29, 30, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 29, 30, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 29, 30, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 29, 30, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 29, 30, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 29, 30, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 29, 30, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 29, 30, 192)  0           ['batch_normalization_53[0][0]']
#
# ...
#
#  batch_normalization_84 (BatchN  (None, 14, 14, 192)  576        ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 14, 14, 320)  0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 14, 14, 768)  0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 14, 14, 768)  0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 14, 14, 2048  0           ['activation_76[0][0]',
#                                 )                                 'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 14, 14, 448)  917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 14, 14, 448)  1344       ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 14, 14, 448)  0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 14, 14, 384)  786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 14, 14, 384)  1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 14, 14, 384)  1152       ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 14, 14, 384)  1152       ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 14, 14, 384)  0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 14, 14, 384)  0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 14, 14, 384)  442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 14, 14, 384)  442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 14, 14, 384)  442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 14, 14, 384)  442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 14, 14, 2048  0          ['mixed9[0][0]']
#  oling2D)                       )
#
#  conv2d_85 (Conv2D)             (None, 14, 14, 320)  655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 14, 14, 384)  1152       ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 14, 14, 384)  1152       ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 14, 14, 384)  1152       ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 14, 14, 384)  1152       ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 14, 14, 192)  393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 14, 14, 320)  960        ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 14, 14, 384)  0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 14, 14, 384)  0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 14, 14, 384)  0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 14, 14, 384)  0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 14, 14, 192)  576        ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 14, 14, 320)  0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 14, 14, 768)  0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 14, 14, 768)  0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 14, 14, 2048  0           ['activation_85[0][0]',
#                                 )                                 'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21,802,208
# Trainable params: 21,767,776
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3407 - accuracy: 0.8574
# Epoch 1: val_accuracy improved from -inf to 0.48718, saving model to .\iv3.hdf5
# 157/157 [==============================] - 83s 484ms/step - loss: 0.3407 - accuracy: 0.8574 - val_loss: 0.6938 - val_accuracy: 0.4872
# Epoch 2/20
# 157/157 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9533
# Epoch 2: val_accuracy did not improve from 0.48718
# 157/157 [==============================] - 69s 439ms/step - loss: 0.1341 - accuracy: 0.9533 - val_loss: 0.8071 - val_accuracy: 0.4872
# Epoch 3/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9696
# Epoch 3: val_accuracy did not improve from 0.48718
# 157/157 [==============================] - 69s 440ms/step - loss: 0.0981 - accuracy: 0.9696 - val_loss: 0.7535 - val_accuracy: 0.4872
# Epoch 4/20
# 157/157 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9665
# Epoch 4: val_accuracy improved from 0.48718 to 0.58494, saving model to .\iv3.hdf5
# 157/157 [==============================] - 74s 471ms/step - loss: 0.1057 - accuracy: 0.9665 - val_loss: 1.1932 - val_accuracy: 0.5849
# Epoch 5/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9772
# Epoch 5: val_accuracy improved from 0.58494 to 0.87981, saving model to .\iv3.hdf5
# 157/157 [==============================] - 75s 478ms/step - loss: 0.0708 - accuracy: 0.9772 - val_loss: 0.3614 - val_accuracy: 0.8798
# Epoch 6/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9788
# Epoch 6: val_accuracy improved from 0.87981 to 0.95353, saving model to .\iv3.hdf5
# 157/157 [==============================] - 73s 465ms/step - loss: 0.0605 - accuracy: 0.9788 - val_loss: 0.1677 - val_accuracy: 0.9535
# Epoch 7/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9792
# Epoch 7: val_accuracy did not improve from 0.95353
# 157/157 [==============================] - 69s 439ms/step - loss: 0.0574 - accuracy: 0.9792 - val_loss: 11.1834 - val_accuracy: 0.5304
# Epoch 8/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9848
# Epoch 8: val_accuracy did not improve from 0.95353
# 157/157 [==============================] - 69s 441ms/step - loss: 0.0468 - accuracy: 0.9848 - val_loss: 1.9364 - val_accuracy: 0.6058
# Epoch 9/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9868
# Epoch 9: val_accuracy improved from 0.95353 to 0.97115, saving model to .\iv3.hdf5
# 157/157 [==============================] - 74s 470ms/step - loss: 0.0442 - accuracy: 0.9868 - val_loss: 0.1888 - val_accuracy: 0.9712
# Epoch 10/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9920
# Epoch 10: val_accuracy did not improve from 0.97115
# 157/157 [==============================] - 69s 438ms/step - loss: 0.0182 - accuracy: 0.9920 - val_loss: 0.9120 - val_accuracy: 0.8574
# Epoch 11/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9784
# Epoch 11: val_accuracy did not improve from 0.97115
# 157/157 [==============================] - 69s 441ms/step - loss: 0.0677 - accuracy: 0.9784 - val_loss: 0.1883 - val_accuracy: 0.9712
# Epoch 12/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9884
# Epoch 12: val_accuracy did not improve from 0.97115
# 157/157 [==============================] - 69s 439ms/step - loss: 0.0330 - accuracy: 0.9884 - val_loss: 3.6419 - val_accuracy: 0.6170
# Epoch 13/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9960
# Epoch 13: val_accuracy did not improve from 0.97115
# 157/157 [==============================] - 69s 441ms/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 0.3112 - val_accuracy: 0.9679
# Epoch 14/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9900
# Epoch 14: val_accuracy did not improve from 0.97115
# 157/157 [==============================] - 69s 439ms/step - loss: 0.0283 - accuracy: 0.9900 - val_loss: 0.4730 - val_accuracy: 0.8846
# Epoch 15/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9948
# Epoch 15: val_accuracy did not improve from 0.97115
# 157/157 [==============================] - 69s 442ms/step - loss: 0.0154 - accuracy: 0.9948 - val_loss: 0.3579 - val_accuracy: 0.9631
# Epoch 16/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9944
# Epoch 16: val_accuracy did not improve from 0.97115
# 157/157 [==============================] - 69s 440ms/step - loss: 0.0199 - accuracy: 0.9944 - val_loss: 1.3866 - val_accuracy: 0.8269
# Epoch 17/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9856
# Epoch 17: val_accuracy did not improve from 0.97115
# 157/157 [==============================] - 69s 437ms/step - loss: 0.0397 - accuracy: 0.9856 - val_loss: 0.4371 - val_accuracy: 0.9679
# Epoch 18/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9968
# Epoch 18: val_accuracy did not improve from 0.97115
# 157/157 [==============================] - 69s 441ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.2352 - val_accuracy: 0.9631
# Epoch 19/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 19: val_accuracy did not improve from 0.97115
# 157/157 [==============================] - 69s 439ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.5760 - val_accuracy: 0.8814
# Epoch 20/20
# 157/157 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9988
# Epoch 20: val_accuracy did not improve from 0.97115
# 157/157 [==============================] - 69s 440ms/step - loss: 0.0024 - accuracy: 0.9988 - val_loss: 0.2322 - val_accuracy: 0.9679
# For InceptionV3
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       162
#            1       0.98      0.96      0.97       189
#
#     accuracy                           0.97       351
#    macro avg       0.97      0.97      0.97       351
# weighted avg       0.97      0.97      0.97       351
#
# 0.9686609686609686
# <Axes: >

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/ba/7c/b971f2485155917ecdcebb210e021e36a6b65457394590be01cc61515310/tensorflow-2.13.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached tensorflow-2.13.0-cp310-cp310-win_amd64.whl.metadata (2.6 kB)
# Collecting tensorflow-intel==2.13.0 (from tensorflow)
#   Obtaining dependency information for tensorflow-intel==2.13.0 from https://files.pythonhosted.org/packages/40/fa/98115f6fe4d92e1962f549917be2dc8e369853b7e404191996fedaaf4dd6/tensorflow_intel-2.13.0-cp310-cp310-win_amd64.whl.metadata
#   Using cached tensorflow_intel-2.13.0-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 from https://files.pythonhosted.org/packages/6f/ac/a065300a39fca3e8eb5df245b1a6a85e4c9768de44c8df3421199bc51440/protobuf-4.24.1-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-4.24.1-cp310-abi3-win_amd64.whl.metadata (540 bytes)
# Requirement already satisfied: setuptools in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.0)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow-intel==2.13.0->tensorflow)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.56.2)
# Collecting tensorboard<2.14,>=2.13 (from tensorflow-intel==2.13.0->tensorflow)
#   Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for tensorflow-estimator<2.14,>=2.13.0 from https://files.pythonhosted.org/packages/72/5c/c318268d96791c6222ad7df1651bbd1b2409139afeb6f468c0f327177016/tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata
#   Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.14,>=2.13.1 (from tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for keras<2.14,>=2.13.1 from https://files.pythonhosted.org/packages/2e/f3/19da7511b45e80216cbbd9467137b2d28919c58ba1ccb971435cb631e470/keras-2.13.1-py3-none-any.whl.metadata
#   Using cached keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.22.0)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow)
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.31.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/da/61/6e9ff8258422d287eec718872fb71e05324356722ab658c8afda25f51539/tensorboard_data_server-0.7.1-py3-none-any.whl.metadata
#   Using cached tensorboard_data_server-0.7.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\.conda\envs\defence\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\.conda\envs\defence\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\.conda\envs\defence\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\.conda\envs\defence\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\.conda\envs\defence\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\.conda\envs\defence\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\user\.conda\envs\defence\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\user\.conda\envs\defence\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\.conda\envs\defence\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# Using cached tensorflow-2.13.0-cp310-cp310-win_amd64.whl (1.9 kB)
# Using cached tensorflow_intel-2.13.0-cp310-cp310-win_amd64.whl (276.5 MB)
# Using cached keras-2.13.1-py3-none-any.whl (1.7 MB)
# Downloading protobuf-4.24.1-cp310-abi3-win_amd64.whl (430 kB)
#    ---------------------------------------- 0.0/430.4 kB ? eta -:--:--
#    -- ------------------------------------- 30.7/430.4 kB 1.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 112.6/430.4 kB 1.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 245.8/430.4 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 430.4/430.4 kB 2.2 MB/s eta 0:00:00
# Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
# Using cached tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Installing collected packages: typing-extensions, tensorflow-estimator, tensorboard-data-server, protobuf, keras, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.10.0
#     Uninstalling tensorflow-estimator-2.10.0:
#       Successfully uninstalled tensorflow-estimator-2.10.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: keras
#     Found existing installation: keras 2.10.0
#     Uninstalling keras-2.10.0:
#       Successfully uninstalled keras-2.10.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.6
#     Uninstalling google-auth-oauthlib-0.4.6:
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.10.1
#     Uninstalling tensorboard-2.10.1:
#       Successfully uninstalled tensorboard-2.10.1
# Successfully installed google-auth-oauthlib-1.0.0 keras-2.13.1 protobuf-4.24.1 tensorboard-2.13.0 tensorboard-data-server-0.7.1 tensorflow-2.13.0 tensorflow-estimator-2.13.0 tensorflow-intel-2.13.0 typing-extensions-4.5.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-gpu 2.10.0 requires keras<2.11,>=2.10.0, but you have keras 2.13.1 which is incompatible.
# tensorflow-gpu 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.24.1 which is incompatible.
# tensorflow-gpu 2.10.0 requires tensorboard<2.11,>=2.10, but you have tensorboard 2.13.0 which is incompatible.
# tensorflow-gpu 2.10.0 requires tensorflow-estimator<2.11,>=2.10.0, but you have tensorflow-estimator 2.13.0 which is incompatible.
